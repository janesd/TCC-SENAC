# %%
# descobrindo qual diretório está fixado, lembrar que o formato é com  C:\\nome\\nome\\  
import os

# para modificar o diretório ...
os.chdir('C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\\')
os.getcwd()
# Out:
# 'C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS'

# %%
import chardet
import pandas as pd

arquivo = "twiter_suicidio_2019_12_14_11_24_16.csv"
cabecalho = ['Usuario','Texto','Data']

with open(arquivo, 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large 
df1 = pd.read_csv(arquivo, encoding=result['encoding'], sep=',', header=None, names=cabecalho)

#df1.head()
df1.count()
df1
# Out:
#                   0                                                  1  \
# 0   ExpertoIgualdad  @gordocontrapo +Si podemos entender que los pr...
# 1           ara_cue  RT @sopitas: Alumnos del ITAM han tomado accio...
# 2           Rosal60  RT @Mariela27389791: @HawkGloves Me pregunto q...
# 3          Marihmr0  RT @azvdofb: tem outra soluo alm do suicdio? m...
# 4        jljuarezmx  RT @jenarovillamil: Creo qu hay un libro clsic...
# 5     Maria40846993  RT @CristinaSegui_: Una madre mata a sus hijas...
# 6       valkiria642  RT @Jasafella: Jams he escuchado eso de "suici...
# 7         AlineFe75  Eu posso ver mil casos de suicdio, que ainda e...
# 8        Odraunem11  RT @ramirezmmx: Sobre lo que pas en el ITAM:  ...
# 9      Franferchile  @JamesHamiltonCL El aporte cultural econmico. ...
# 10         Damartma  RT @Alvisepf: Hace unas horas ha fallecido la ...
# 11  Leticia22996590  RT @MiguelMezaC: Ante el suicidio de Fer, nues...
# ...

# %%
arquivo = "twiter_suicídio_2019_12_14_11_31_42.csv"

with open(arquivo, 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large
    
df2 = pd.read_csv(arquivo, encoding=result['encoding'], sep=',', header=None, names=cabecalho)
#df2.head()
df2.count()
df2
# Out:
#                   0                                                  1  \
# 0         shitworId  RT @CVVoficial: (1/9) #SetembroAmarelo est a e...
# 1        medeirostv  Foi aprovada nos EUA a criao de um atendimento...
# 2          luvblog_  RT @tantotupiassu: Converse claramente sobre s...
# 3        euceciliaj  RT @tantotupiassu: Converse claramente sobre s...
# 4       scrazyweird  RT @tantotupiassu: Converse claramente sobre s...
# 5      JANJINHA0301  Quem realiza uma tentativa de suicdio tentar, ...
# 6         LuizaPeeh  RT @tantotupiassu: Converse claramente sobre s...
# 7      larisantosr_  Meu TCC foi sobre suicdio e um ano depois eu d...
# 8         raninhapv  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# 9        ahbandeira  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# 10  m2claudiomendes  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# 11     bernardino_f  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# ...

# %%
arquivo = "twiter_suicídio_2019_12_14_11_39_04.csv"

with open(arquivo, 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large
    
df3 = pd.read_csv(arquivo, encoding=result['encoding'], sep=',', header=None, names=cabecalho)
#df3.head()
df3.count()
df3
# Out:
#                   0                                                  1  \
# 0         shitworId  RT @CVVoficial: (1/9) #SetembroAmarelo est a e...
# 1        medeirostv  Foi aprovada nos EUA a criao de um atendimento...
# 2          luvblog_  RT @tantotupiassu: Converse claramente sobre s...
# 3        euceciliaj  RT @tantotupiassu: Converse claramente sobre s...
# 4       scrazyweird  RT @tantotupiassu: Converse claramente sobre s...
# 5      JANJINHA0301  Quem realiza uma tentativa de suicdio tentar, ...
# 6         LuizaPeeh  RT @tantotupiassu: Converse claramente sobre s...
# 7      larisantosr_  Meu TCC foi sobre suicdio e um ano depois eu d...
# 8         raninhapv  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# 9        ahbandeira  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# 10  m2claudiomendes  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# 11     bernardino_f  RT @valteraguiar: Povo de Santos! Dia 7/12 s 9...
# ...

# %%
df = pd.concat([df1, df2, df3], axis=0, join='inner')
#df.set_index('DateTime', inplace=True)
df.count()
# Out:
# 0    126
# 1    126
# 2    126
# 3    126
# dtype: int64

# %%
#print(df.head())
df.to_csv('df.csv')

# %% [markdown]
# ## Segunda tentativa

# %%
import glob
import os
import pandas as pd

os.chdir('C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\\')
cabecalho = ['Id','Usuario','Texto','Data']

folder_name = 'DADOS'
file_type = 'csv'
separator =','

dataframe = pd.concat([pd.read_csv(f, sep=separator, header=None, names = cabecalho) for f in glob.glob(folder_name + "/*."+file_type)], ignore_index=True, axis=0)
dataframe.to_csv('total_arquivos.csv')

# %%
dataframe.count()
# Out:
# Usuario    465
# Texto      465
# Data       465
# dtype: int64

# %%
# para listar o nome dos arquivos de um diretório
import glob
import pandas as pd

# get data file names
path =r'C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\\'
filenames = glob.glob(path + "/*.csv")

for arquivo in filenames:
    print('arquivo= %s ', filename )
# Out:
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# arquivo= %s  C:\\Users\\particular\\SERIQUE_TCC\\CAPTURA TWITTERS\twiter_suicídio_2019_12_14_11_39_04.csv
# ...

# %% [markdown]
# ## trabalhando com emojis

# %%
#pip install emoji --upgrade
#pip install regex

# %%
import emoji
import regex

def split_count(text):
    emoji_counter = 0
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_counter += 1
            # Remove from the given text the emojis
            text = text.replace(word, '') 

    words_counter = len(text.split())

    return emoji_counter, words_counter

# %%
line = "hello 👩🏾‍🎓 emoji hello 👨‍👩‍👦‍👦 how are 😊 you today🙅🏽🙅🏽"
counter = split_count(line)
print("Number of emojis - {}, number of words - {}".format(counter[0], counter[1]))
# Out:
# Number of emojis - 5, number of words - 7
